# %%
#range() - in Python 3, xrange() was replaced by range()

a=range(1,10)
print(a)
print(type(a))

x=range(1,10)
print(x)
print(type(x))
# Out:
# range(1, 10)
# <class 'range'>
# range(1, 10)
# <class 'range'>

# %%
#memory usage of range() and 


import sys

# initializing a with range()
a = range(1,10000)

# initializing a with xrange()
x = xrange(1,10000)

# testing the size of a
# range() takes more memory
print ("The size allotted using range() is : ")
print (sys.getsizeof(a))

# testing the size of x
# xrange() takes less memory
print ("The size allotted using xrange() is : ")
print (sys.getsizeof(x))

# %%
# Python code to demonstrate range() vs xrange()
# on  basis of operations usage 

# initializing a with range()
a = range(1,6)

# initializing a with xrange()
x = range(1,6)

# testing usage of slice operation on range()
# prints without error
print ("The list after slicing using range is : ")
print (a[2:5])

# testing usage of slice operation on xrange()
# raises error
print ("The list after slicing using xrange is : ")
print (x[2:5])
# Out:
# The list after slicing using range is :
# range(3, 6)
# The list after slicing using xrange is :
# range(3, 6)

# %% [markdown]
# ![alt text](image.png)

# %%
#using else with for loop
for i in range(5):
    print(i)
    
else:
    print("Loop completed")
    print("Else block executed")
# Out:
# 0
# 1
# 2
# 3
# 4
# Loop completed
# Else block executed

# %%
for i in range(5):
    print(i)
    break
    
else:
    print("Loop completed")
# Out:
# 0

# %%
def contains_even_number(l):

  for ele in l:
      if ele % 2 == 0:
          print("list contains an even number")
      else:
          print("list does not contain an even number")


print("For List 1:")
contains_even_number([1, 9, 8])
print("For List 2:")
contains_even_number([1, 3, 5])
# Out:
# For List 1:
# list does not contain an even number
# list does not contain an even number
# list contains an even number
# For List 2:
# list does not contain an even number
# list does not contain an even number
# list does not contain an even number

# %%
count = 0
while (count < 1):    
    count = count+1
    print(count)
    break
else:
    print("No Break")
# Out:
# 1

# %%
# flow control statements in loops
for letter in 'varun':
    if letter == 'u':
        continue #break
    print(format(letter))
# Out:
# v
# a
# r
# n

# %%
for letter in 'varun':
    pass
print(letter)
# Out:
# n

# %%
def checkOddEven(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"
# Out:
# False

# %%
def multplicationtable(n):
    for i in range(1,11):
        print(n*i)

# %%
def stringJumper(s):
    for idx in range(0, len(s), 2):
        print(s[idx], end="")

# %%
def printInDecreasing(x):
    while x >= 0:
        print(x, end=" ")
        x -= 1

# use existing variable from the notebook
printInDecreasing(count)

# %%
def printIncreasingPower(x):
    # Print numbers in increasing powers of 2 up to x (inclusive)
    # Supports int or an iterable (e.g., range) by using its max value
    try:
        limit = int(x)
    except TypeError:
        limit = max(x)

    if limit < 1:
        return

    val = 1
    while val <= limit:
        print(val, end=" ")
        val *= 2
    print()  # newline

# Use existing variable `a` (range(1, 6)) -> prints: 1 2 4
printIncreasingPower(a)

# %%
def printIncreasingPower(x):
    try:
        limit = int(x)
    except (TypeError, ValueError):
        limit = max(x)

    if limit < 1:
        return

    i = 1
    while i * i <= limit:
        print(i * i, end=" ")
        i += 1
    print()

# %% [markdown]
# def cat_hat(str):
#     # Count occurrences of 'cat' and 'hat'
#     count_cat = str.count("cat")
#     count_hat = str.count("hat")
#
#     # Compare counts
#     return count_cat == count_hat

# %%
for i in range(1, 6, 2):
    print(i, end=' ')
# Out:
# 1 3 5

# %%
count = 0
while count < 3:
    count += 1
    if count == 2:
        continue
    print(count, end=' ')
# Out:
# 1 3
