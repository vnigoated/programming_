# %%
#functions in python
def fun():
    print("helloo")
fun()
# Out:
# helloo

# %%
def evenodd(x):
    if x%2==0:
        print("even")
    else:
        print("odd")
evenodd(5)
evenodd(6)
# Out:
# odd
# even

# %%
def myfun(x,y=40):
    print(x, "+", y, "=", x+y)
myfun(10)
# Out:
# 10 + 40 = 50

# %%
def student(firstname, lastname):
	print(firstname, lastname)


student(firstname='Varun', lastname='Inamdar')
student(lastname='abc', firstname='xyz')
# Out:
# Varun Inamdar
# xyz abc

# %%
# Python program to illustrate
# *args for variable number of arguments
def myFun(*argv):
	for arg in argv:
		print(arg)


myFun('Hello', 'Welcome', 'to', 'ipynb')
# Out:
# Hello
# Welcome
# to
# ipynb

# %%
def myFun(**kwargs):
	for key, value in kwargs.items():
		print("%s == %s" % (key, value))

# Driver code
myFun(first='varun', mid='nikhil', last='inamdar')
# Out:
# first == varun
# mid == nikhil
# last == inamdar

# %%
# A simple Python function to check
# whether x is even or odd
def evenOdd(x):
	"""Function to check if the number is even or odd"""
	if (x % 2 == 0):
		print("even")
	else:
		print("odd")

# Driver code to call the function
print(evenOdd.__doc__)
evenOdd(3)
# Out:
# Function to check if the number is even or odd
# odd

# %%
def swap(x,y):
    temp=x
    x=y
    y=temp

x=5
y=10
swap(x,y)
print(x,y)  #values will not be swapped
# Out:
# 5 10

# %%
li =['a', 'b', 'c', 'd']
 
for i in li:
    if(i =='a'):
        pass
    else:
        print(i)
# Out:
# b
# c
# d

# %%
def print_even(test_list) :
    for i in test_list:
        if i % 2 == 0:
            yield i

# initializing list
test_list = [1, 4, 5, 6, 7]

# printing initial list
print ("The original list is : " + str(test_list))

# printing even numbers
print ("The even numbers in list are : ", end = " ")
for j in print_even(test_list):
    print (j, end = " ")
# Out:
# The original list is : [1, 4, 5, 6, 7]
# The even numbers in list are :  4 6
