# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Logistic_regression.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, color='red', marker='+')

# %%
# %pip install scikit-learn
from sklearn.model_selection import train_test_split
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\vnina\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\vnina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (2.1.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\vnina\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.15.2)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.7.2 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
train_test_split(df.age, df.bought_insurance, test_size=0.1)
# Out:
# [5     56
#  13    29
#  16    25
#  18    19
#  10    18
#  19    18
#  0     22
#  8     62
#  22    40
#  4     46
#  23    45
#  12    27
#  11    28
#  15    55
#  26    23
#  2     47
#  17    58
#  1     25
#  3     52
#  24    50
#  20    21
#  7     60
#  21    26
#  6     55
#  Name: age, dtype: int64,
#  9     61
#  14    49
#  25    54
#  Name: age, dtype: int64,
#  5     1
#  13    0
#  16    1
#  18    0
#  10    0
#  19    0
#  0     0
#  8     1
#  22    1
#  4     1
#  23    1
#  12    0
#  11    0
#  15    1
#  26    0
#  2     1
#  17    1
#  1     0
#  3     0
#  24    1
#  20    0
#  7     1
#  21    0
#  6     0
#  Name: bought_insurance, dtype: int64,
#  9     1
#  14    1
#  25    1
#  Name: bought_insurance, dtype: int64]

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size=0.1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 1, 1])

# %%
model.score(x_test, y_test)
# Out:
# 0.6666666666666666

# %%
prediction = model.predict([[23]])
# Out:
# C:\Users\vnina\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
